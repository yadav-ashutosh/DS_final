# %%
import pandas as pd
df = pd.read_csv('https://code.datasciencedojo.com/datasciencedojo/datasets/raw/master/Default%20of%20Credit%20Card%20Clients/default%20of%20credit%20card%20clients.csv', header=1)

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.842267      1.557267
# std     8660.398374   129747.661567      0.489129      0.744494      0.521405
# min        1.000000    10000.000000      1.000000      1.000000      1.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      4.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# dpnm         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_0      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  PAY_AMT1   30000 non-null  int64
#  14  PAY_AMT2   30000 non-null  int64
#  15  PAY_AMT3   30000 non-null  int64
#  16  PAY_AMT4   30000 non-null  int64
#  17  PAY_AMT5   30000 non-null  int64
#  18  PAY_AMT6   30000 non-null  int64
#  19  dpnm       30000 non-null  int64
# ...

# %%
duplicates = df.duplicated()
print("Number of duplicates:", duplicates.sum())
# Out:
# Number of duplicates: 0

# %% [markdown]
# #EDA

# %%
# import visualization libraries
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Step by step we will analyse Education , Marriage and gender columns

# %%
df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %%
df['EDUCATION'].replace({5: 4, 6: 4, 0: 4}, inplace=True)

# %%
education_map = {
    1: 'Graduate School',
    2: 'University',
    3: 'High School',
    4: 'Others'  # 5, 6, and 0 have been replaced by 4
}

df['EDUCATION'] = df['EDUCATION'].map(education_map)

# Grouping by EDUCATION and calculating the count of defaulters
defaulter_count = df[df['dpnm'] == 1].groupby('EDUCATION')['dpnm'].count()

#bar plot
plt.figure(figsize=(8, 6))
plt.bar(defaulter_count.index, defaulter_count.values)
plt.xlabel('Education Level')
plt.ylabel('Number of Defaulters')
plt.title('Number of Defaulters by Education Level')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
df['MARRIAGE'].replace({ 0: 3}, inplace=True)

# %%
Marriage_map = {
    1: 'Married',
    2: 'Single',
    3: 'Others'
}

df['MARRIAGE'] = df['MARRIAGE'].map(Marriage_map)

defaulter_count = df[df['dpnm'] == 1].groupby('MARRIAGE')['dpnm'].count()

# Create the bar plot
plt.figure(figsize=(8, 6))
plt.bar(defaulter_count.index, defaulter_count.values)
plt.xlabel('Marriage status')
plt.ylabel('Number of Defaulters')
plt.title('Number of Defaulters by Martial status')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %%
df['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
defaulter_percent = df.groupby('SEX')['dpnm'].mean() * 100

# Create the histogram
plt.figure(figsize=(6, 4))
plt.bar(defaulter_percent.index, defaulter_percent.values)
plt.xlabel('SEX (1: Male, 2: Female)')
plt.ylabel('Percentage of Defaulters')
plt.title('Percentage of Defaulters by Gender')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
n, bins, patches = plt.hist(df['AGE'], bins=5)  # You can adjust the number of bins as needed

# Calculate the count of people in each bin and annotate the bars
for i in range(len(patches)):
    plt.text(bins[i], n[i], f"{int(n[i])}", ha='center', va='bottom')

plt.xlabel('Age')
plt.ylabel('Number of Entries')
plt.title('Number of Entries in Each Age Group')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Analysis of Payments, Bills and Amounts

# %%
df.rename(columns={'default payment next month': 'dpnm'}, inplace=True)

# %%
features = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
target = 'dpnm'

# Create a histogram subplot for each feature vs 'dpnm'
def make_subplots(features, target):
  plt.figure(figsize=(13, 9))
  for i, feature in enumerate(features, 1):
      plt.subplot(2, 3, i)
      plt.hist([df[df[target] == 0][feature], df[df[target] == 1][feature]], bins=20, alpha=0.7, label=['dpnm=0', 'dpnm=1'])
      plt.xlabel(feature)
      plt.ylabel('Count')
      plt.legend()

  plt.tight_layout()
  plt.show()

make_subplots(features, target)

# %%
features = features = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
make_subplots(features, target)

# %%
features = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
make_subplots(features, target)

# %% [markdown]
# The pay and bill amount plots are right skewed, it can be normalised in preprocessing

# %% [markdown]
# #Visualization and observations

# %%
plt.figure(figsize=(8, 6))
sn.boxplot(x='dpnm', y='LIMIT_BAL', data=df)
plt.xlabel('Default payments')
plt.ylabel('Limit balance')
plt.title('Box Plot of Limit balance for Default payments')
plt.grid(True)
plt.show()

# %% [markdown]
# Correalation matrix to check if we can reduce any features. We will remove a feature which has more than 0.9 correlation with another feature

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sn.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})

plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# We can see that bill amounts are correlated with each other , during  feature engineering they can be clubbed.

# %%
import numpy as np

def remove_correlated_features(df_temp, threshold=0.9):
    corr_matrix = df_temp.corr().abs()
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
    to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]
    df_temp.drop(columns=to_drop, inplace=True)
    return df_temp

df_temp = df

X_2 = remove_correlated_features(df_temp, threshold=0.9)
# Out:
# <ipython-input-20-13458142add6>:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Empty DataFrame

# %% [markdown]
# #Prediction

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Step 1: Handle correlated features (assumption: X_2 contains the features with correlation > 0.9 already removed)
y = df['dpnm'].copy()
y.sample(5)

features = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
X = df.drop(columns=['dpnm']).copy()
X.columns
# Step 2: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Step 3: Create and train the logistic regression model
logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_train, y_train)

# Step 4: Make predictions on the test data
y_pred = logistic_model.predict(X_test)

from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.7811666666666667
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      4687
#            1       0.00      0.00      0.00      1313
#
#     accuracy                           0.78      6000
#    macro avg       0.39      0.50      0.44      6000
# weighted avg       0.61      0.78      0.69      6000
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# #Decision Tree classifier

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.model_selection import train_test_split

# %%
y = df['dpnm'].copy()
y.sample(5)
# Out:
# 17853    0
# 5620     0
# 26477    0
# 6304     1
# 18019    1
# Name: default payment next month, dtype: int64

# %%
# create the features, which now will be everything in the original df
features = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
X = df[features].copy()
X.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42 , stratify = y)

# %%
classifier = DecisionTreeClassifier(max_depth=10, random_state=14)

classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.8096666666666666

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test , y_pred= predictions)

# %%
print(f1)
# Out:
# 0.44990366088631983
